# %%
# %load_ext autoreload
# %autoreload 2
# %qtconsole

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
sns.set(style="white")

# %%
X = pd.read_pickle("./dati.pkl")
y = pd.read_pickle("./y.pkl")

# %%
Xm = X.mean(axis=0)

# %%
X-=Xm

# %%
U, s, Vt = np.linalg.svd(X, full_matrices=False)

# %% [markdown]
# Due componenti principali non sono sufficienti, spiegano circa il 3% della variabilità dei dati.

# %%
plt.plot(range(len(s)), s/s.sum() * 100, marker='o', )

# %%
temp = np.dot(U, np.diag(s))

# %%
pca = PCA(n_components=2, random_state=42)
prinComp = pca.fit_transform(X)

# %%
sns.jointplot(prinComp[:, 0], prinComp[:, 1], kind="hex")
